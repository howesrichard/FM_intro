# %%
# !pip install matplotlib matplotlib-inline numpy pandas requests yfinance ipywidgets fpdf lxml
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 40.1 MB/s  0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 54.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 51.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 33.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 45.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 51.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 55.2 MB/s  0:00:00
# ...

# %%
import matplotlib
import matplotlib_inline
import numpy as np
import pandas as pd
import requests
import yfinance as yf
import ipywidgets as widgets
from fpdf import FPDF
import lxml

# %%
# Step 1: helper functions (fill in later)

# TODO: create small utilities here. Suggested stubs:


# - load_commentary(path: str) -> str (pull text from assets/commentary.txt)

# - get_price_history(ticker: str, period: str, interval: str) -> DataFrame (yfinance)

# - compute_simple_metrics(df) -> dict (latest price, return, vol, fwd PE using API EPS)

# Keep only function definitions and docstrings; no external calls in this cell.

# %%
# Step 2: pull live data from API (yfinance)

# TODO:

# - set ticker symbol

# - call your get_price_history() helper to fetch price data

# - store results as price_history and metrics

# - fetch forward EPS / key metrics via yf.Ticker for ratios

# Do not run heavy downloads here until ready; keep code commented until needed.

# %%
# Step 3: scrape data (text + table + image)

# TODO:

# - Use requests + lxml or pandas.read_html to grab a company profile paragraph online

# - Also load local assets: image in assets/stock_market.jpg, commentary.txt, csv/xlsx

# - Save scraped about_text and any tables (e.g., execs) for later use

# - Keep network calls commented until ready to run

# %%
# Step 4: analyze and visualize

# TODO:

# - Create plots (e.g., price history, SMA) using price_history from Step 2

# - Build metrics_table DataFrame for PDF export

# - Keep plotting code here; no execution until data is loaded

# %%
# Step 5: assemble PDF report + CSV/XLSX inputs

# TODO:

# - Load commentary from assets/commentary.txt

# - Load price targets CSV/XLSX and ASX200 history CSV from assets/

# - Insert chart image from Step 4 and existing assets image (assets/stock_market.jpg)

# - Use FPDF to create report with metrics table, commentary, scraped about_text

# - Export to outputs/research_report.pdf

# Keep as scaffolding until data is ready; comment out file writes if testing
